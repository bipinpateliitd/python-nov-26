# %% [markdown]
# - special methods are also called magic methods or dunder methods
#
# 🔮 What are Magic (Special) Methods?
#
# Magic methods are predefined methods that Python automatically calls in specific situations.
#
# Example:
#
# Creating an object → __init__
#
# Printing an object → __str__
#
# Using + operator → __add__

# %% [markdown]
# 1️⃣ Object Creation & Initialization
#
# - '__init__'
#
# Called when an object is created (constructor).

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

# %%
class Car1:
    def __str__(self):
        return "This is a car"
c1 = Car1()

# %%
class Car2:
    def show(self):
        return "This is a car"

c2 = Car2()

# %%
print(c1)
# Out:
# This is a car

# %%
print(c2)

# %%
c2.show()
# Out:
# 'This is a car'

# %%
class Car2:
    def show(self):
        return "This is a car"

c2 = Car2()

# %%
c2.show()

# %%
print(c2)

# %%
print(c1)

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    def __str__(self):
        return f"'{self.title}' by {self.author}"
    
    #def abc(self):
        #return f"'{self.title}' by {self.author}"

# %%
c1=Book("abc","xyz",34)

# %%
print(c1)
# Out:
# 'abc' by xyz

# %%
c1.abc()
# Out:
# "'abc' by xyz"

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    
    # String representation for print()
    def __str__(self):
        return f"'{self.title}' by {self.author}"
    
    
    # Length of the book
    def __len__(self):
        return self.pages
    
    # Comparison operators
    def __eq__(self, other):
        return self.pages == other.pages
    
    def __lt__(self, other):
        return self.pages < other.pages
    
    # Addition operator
    def __add__(self, other):
        return self.pages + other.pages

# %%
x=[1,4,5]

# %%
len(x)
# Out:
# 3

# %%
print(type(x))
# Out:
# <class 'list'>

# %%
book1 = Book("Python Crash Course", "Eric Matthes", 544)
book2 = Book("Automate the Boring Stuff", "Al Sweigart", 544)

# %%
book1 == book2
# Out:
# True

# %%
book1 < book2
# Out:
# False

# %%
book1+book2
# Out:
# 1088

# %%
book1.pages
# Out:
# 544

# %%
print(f"Are books equal? {book1 == book2}")  # Uses __eq__
print(f"Is book1 shorter? {book1 < book2}")  # Uses __lt__
print(f"Total pages: {book1 + book2}")  # Uses __add__
# Out:
# Are books equal? False
# Is book1 shorter? True
# Total pages: 1136

# %%
print(f"Book 1 has {len(book1)} pages")  # Uses __len__
# Out:
# Book 1 has 544 pages

# %%
len(book1)
# Out:
# 544

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    
    # String representation for print()
    def __str__(self):
        return f"'{self.title}' by {self.author}"
    
    
    # Length of the book
    def __len__(self):
        return self.pages
    
    # Comparison operators
    def __eq__(self, other):
        return self.pages == other.pages
    
    def __lt__(self, other):
        return self.pages < other.pages
    
    # Addition operator
    def __add__(self, other):
        return self.pages + other.pages

# Using the class
book1 = Book("Python Crash Course", "Eric Matthes", 544)
book2 = Book("Automate the Boring Stuff", "Al Sweigart", 592)

print(book1)  # Uses __str__
print(f"Book 1 has {len(book1)} pages")  # Uses __len__
print(f"Are books equal? {book1 == book2}")  # Uses __eq__
print(f"Is book1 shorter? {book1 < book2}")  # Uses __lt__
print(f"Total pages: {book1 + book2}")  # Uses __add__

# %%
class Number:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return self.value + other.value

# %%
n1= Number(23)
n2=Number(54)

# %%
y= n1+n2

# %%
y2=n1-n2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 y2=n1-n2
#
# TypeError: unsupported operand type(s) for -: 'Number' and 'Number'

# %%
y
# Out:
# 77

# %%
class Number:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return Number(self.value + other.value)

    def __sub__(self, other):
        return Number(self.value - other.value)

    def __mul__(self, other):
        return Number(self.value * other.value)

    def __str__(self):
        return str(self.value)

# %%
n1=Number(52)
n2=Number(82)

# %%
y1=n1+n2
print(y1)
# Out:
# 134

# %%
y1=n1*n2
print(y1)
# Out:
# 4264

# %%
n1 = Number(10)
n2 = Number(5)

print(n1 + n2)   # 15
print(n1 - n2)   # 5
print(n1 * n2)   # 50

# %%
a = [1, 2, 3]
b = [4, 5, 6]

print(a + b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
z1=zip(a,b)

# %%
print(z1)

# %%
#[5,7,9]

# %%
z= [a+b for a,b in zip(a,b)]

# %%
z
# Out:
# [5, 7, 9]

# %%
class Vector:
    def __init__(self, values):
        self.values = values

    def __add__(self, other):
        z=[a+b for a,b in zip(self.values,other.values)]
        return Vector(z)
    def __str__(self):
        return str(self.values)

# %%
v1 = Vector([1, 2, 3])

v2 = Vector([4, 5, 6])

# %%
out1= v1+v2

# %%
print(out1)
# Out:
# [5, 7, 9]

# %%
class Vector:
    def __init__(self, values):
        self.values = values

    def __add__(self, other):
        result = [a + b for a, b in zip(self.values, other.values)]
        return Vector(result)

    def __str__(self):
        return str(self.values)

# %%
v1 = Vector([1, 2, 3])
v2 = Vector([4, 5, 6])

v3 = v1 + v2
print(v3)

# %%
a = [1, 2, 3]
b = [4, 5, 6]

z = zip(a, b)
print(list(z))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %% [markdown]
# - Instance Method
#
# Works on object data.

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

    def show(self):
        print(self.brand)

# %%
c = Car("Tata")
c.show()
# Out:
# Tata

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        self.balance -= amount
acc = BankAccount(1000)
acc.withdraw(200)

# %% [markdown]
# 3️⃣ Class Method (@classmethod)
#
# 🔹 Definition
#
# A class method works with the class itself, not a specific object.
#
# - Uses cls
#
# - Can access class variables
#
# - Can create objects

# %%
class Car:
    total_cars = 0   # class variable

    def __init__(self, brand):
        self.brand = brand
        Car.total_cars += 1

    @classmethod
    def show_total(cls):
        print("Total cars:", cls.total_cars)

# %%
c1 = Car("Tata")
c2 = Car("Mahindra")

# %%
Car.show_total()
# Out:
# Total cars: 4

# %%
class BankAccount:
    total_accounts = 0

    def __init__(self):
        BankAccount.total_accounts += 1

    @classmethod
    def get_total_accounts(cls):
        return cls.total_accounts

# %%
a1 = BankAccount()
a2 = BankAccount()

print(BankAccount.get_total_accounts())
# Out:
# 2

# %%
class User:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    @classmethod  #alternative constructor
    def from_birth_year(cls, name, birth_year):
        return cls(name, 2025 - birth_year)

# %%
u = User("Amit",23)
u.age

u1= User.from_birth_year("Amit", 2012)

u1.age
# Out:
# 13

# %% [markdown]
# 5️⃣ Static Method (@staticmethod)
# 🔹 Definition
#
# - A static method is a normal function placed inside a class for logical grouping.
#
# - No self
#
# - No cls
#
# - Cannot access instance or class data directly

# %%
class User:
    def __init__(self, age):
        self.age = age

    @staticmethod
    def is_valid_age(age):
        return age >= 18

# %%
print(User.is_valid_age(20))   # True
# Out:
# True

# %%
class Temperature:
    def __init__(self, celsius):
        self.celsius = celsius

    @staticmethod
    def c_to_f(c):
        return (c * 9/5) + 32

# %%
print(Temperature.c_to_f(30))
# Out:
# 86.0

# %%
class Pizza:
    def __init__(self, ingredients):
        self.ingredients = ingredients
    
    def __str__(self):
        return f"Pizza with {', '.join(self.ingredients)}"
    
    # Class method - alternative constructor
    @classmethod
    def margherita(cls):
        return cls(['mozzarella', 'tomatoes', 'basil'])
    
    @classmethod
    def pepperoni(cls):
        return cls(['mozzarella', 'tomatoes', 'pepperoni'])
    
    # Static method - utility function
    @staticmethod
    def is_valid_ingredient(ingredient):
        forbidden = ['pineapple']  # Controversial!
        return ingredient.lower() not in forbidden

# Using class methods
pizza1 = Pizza.margherita()
pizza2 = Pizza.pepperoni()

print(pizza1)
print(pizza2)

# Using static method
print(f"Is 'mushroom' valid? {Pizza.is_valid_ingredient('mushroom')}")
print(f"Is 'pineapple' valid? {Pizza.is_valid_ingredient('pineapple')}")
# Out:
# Pizza with mozzarella, tomatoes, basil
# Pizza with mozzarella, tomatoes, pepperoni
# Is 'mushroom' valid? True
# Is 'pineapple' valid? False

# %%
#property decorators

# %%
class User:
    def __init__(self, age):
        self.age = age

# %%
u1=User(34)

# %%
u1.age =-5

# %%
u1.age
# Out:
# -5

# %%
u = User(20)
u.age = -5  
#No validation. No control.

# %% [markdown]
# 3️⃣ Enter @property (Pythonic Way ✅)
#
# Core Idea
#
# Access methods like attributes

# %%
class User:
    def __init__(self, age):
        self._age = age   # internal variable


    @property
    def age2(self):
        return self._age

# %%
u1=User(45)
u1._age
# Out:
# 45

# %%
u1.age2
# Out:
# 45

# %%
u = User(20)
print(u.age)   # looks like variable, calls method

# %% [markdown]
# 4️⃣ Adding Setter (@property_name.setter)

# %%
class User:
    def __init__(self, age):
        self._age = age

    @property #getter
    def age(self):
        return self._age
    
    
    @age.setter
    def age(self, value):
        if value < 0:
            raise ValueError("Age cannot be negative")
        self._age = value

# %%
a1= User(34)

# %%
a1.age
# Out:
# 34

# %%
a1.age=-23
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 a1.age=-23
#
# Cell In[186], line 13, in User.age(self, value)
#      10 @age.setter
#      11 def age(self, value):
#      12     if value < 0:
# ---> 13         raise ValueError("Age cannot be negative")
#      14     self._age = value
#
# ValueError: Age cannot be negative

# %%
a1.age
# Out:
# 45

# %%
a1._age=43

# %%
a1._age
# Out:
# 43

# %%
u = User(20)
u.age = 25     # calls setter
print(u.age)

# %%
class BankAccount:
    def __init__(self, balance):
        self._balance = balance

    @property
    def balance(self):
        return self._balance

    @balance.setter
    def balance(self, amount):
        if amount < 0:
            raise ValueError("Balance cannot be negative")
        self._balance = amount

# %%
bal = BankAccount(120)

# %%
bal.balance
# Out:
# 120

# %%
bal.balance=500

# %%
class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius
    
    # Getter
    @property
    def celsius(self):
        return self._celsius
    
    # Setter
    @celsius.setter
    def celsius(self, value):
        if value < -273.15:
            raise ValueError("Temperature below absolute zero is not possible")
        self._celsius = value
    
    # Property for Fahrenheit
    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32
    
    @fahrenheit.setter
    def fahrenheit(self, value):
        self._celsius = (value - 32) * 5/9

# Using the class
temp = Temperature(25)
print(f"Temperature: {temp.celsius}°C = {temp.fahrenheit}°F")

# Setting via property
temp.fahrenheit = 100
print(f"After setting to 100°F: {temp.celsius}°C")

# Validation
try:
    temp.celsius = -300
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Temperature: 25°C = 77.0°F
# After setting to 100°F: 37.77777777777778°C
# Error: Temperature below absolute zero is not possible

# %% [markdown]
# logging, raise error exceptions (try exception and file operations)
