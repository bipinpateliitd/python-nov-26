# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama


from dotenv import load_dotenv
load_dotenv(dotenv_path="/home/bipin/Documents/genai/g25-nov-hindi/python-nov/.env")

#"gpt-5-nano"
#granite4:latest
#gemini-2.5-flash
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-5-nano") # model intialization

# %%
# lets create some attractive advertisment for a shop for tv or print for indian context

# %%
shop_name= "Mishra chat bhandar"
product= "chat, smaosha, phulki"
punch_line="isse tasty kuch bhi nahi "
medium= "hording"
language= "hindi"

# %%
input_msg = f"you are highly experinced indian advertisment creator, create a catchy advertisment for the shop name: {shop_name} for the product: {product} for medium is : {medium} in this language:{language} and this is the punch line: {punch_line}"
print(input_msg)
# Out:
# you are highly experinced indian advertisment creator, create a catchy advertisment for the shop name: Mishra chat bhandar for the product: chat, smaosha, phulki for medium is : hording in this language:hindi and this is the punch line: isse tasty kuch bhi nahi

# %%
output =model.invoke(input_msg)
output_message=output.content
print(output_message)
# Out:
# नीचे तीन catchy hoarding copy विकल्प दिए हैं जिनमें shop name, products (चाट, समोसा, फुल्की) और punch line सही तरह से शामिल है. आप इनमें से कोई भी चुन सकते हैं, या चाहें तो मैं इन्हें आपके ब्रांड फ़ॉन्ट/कलर के हिसाब से और पर्सनलाइज कर दूँ।
#
# विकल्प 1: देसी क्लासिक
# - शीर्षक: मिश्रा चाट भंडार
# - उपशीर्षक: चाट • समोसा • फुल्की
# - मुख्य टेक्स: ताजा मसालों का देसी धमाका, हर निवाला क्रंच, हर स्वाद यादगार
# - punch line: isse tasty kuch bhi nahi
# - CTA/फुटर: आज ही आइए, स्वाद की मिसाल बने
#
# विकल्प 2: न्यू-लोकल, बोल्ड
# - शीर्षक: मिश्रा चाट भंडार
# - उपशीर्षक: चाट • समोसा • फुल्की
# - मुख्य टेक्स: क्रंची चाट, गोल्डन समोसा, खस्ता फुल्की – मज़ा जो मूड के साथ बदले
# - punch line: isse tasty kuch bhi nahi
# - CTA/फुटर: अभी आकर टेस्ट करें, स्ट्रीट-फूड का असली अवार्ड
#
# विकल्प 3: रंगीन त्योहार-सी महफिल
# - शीर्षक: मिश्रा चाट भंडार
# - उपशीर्षक: चाट • समोसा • फुल्की
# - मुख्य टेक्स: रंग-बिरंगे मसालों की महफिल, हर प्लेट में देसी प्यार और ताजगी
# - punch line: isse tasty kuch bhi nahi
# ...

# %%
output
# Out:
# AIMessage(content='नीचे तीन catchy hoarding copy विकल्प दिए हैं जिनमें shop name, products (चाट, समोसा, फुल्की) और punch line सही तरह से शामिल है. आप इनमें से कोई भी चुन सकते हैं, या चाहें तो मैं इन्हें आपके ब्रांड फ़ॉन्ट/कलर के हिसाब से और पर्सनलाइज कर दूँ।\n\nविकल्प 1: देसी क्लासिक\n- शीर्षक: मिश्रा चाट भंडार\n- उपशीर्षक: चाट • समोसा • फुल्की\n- मुख्य टेक्स: ताजा मसालों का देसी धमाका, हर निवाला क्रंच, हर स्वाद यादगार\n- punch line: isse tasty kuch bhi nahi\n- CTA/फुटर: आज ही आइए, स्वाद की मिसाल बने\n\nविकल्प 2: न्यू-लोकल, बोल्ड\n- शीर्षक: मिश्रा चाट भंडार\n- उपशीर्षक: चाट • समोसा • फुल्की\n- मुख्य टेक्स: क्रंची चाट, गोल्डन समोसा, खस्ता फुल्की – मज़ा जो मूड के साथ बदले\n- punch line: isse tasty kuch bhi nahi\n- CTA/फुटर: अभी आकर टेस्ट करें, स्ट्रीट-फूड का असली अवार्ड\n\nविकल्प 3: रंगीन त्योहार-सी महफिल\n- शीर्षक: मिश्रा चाट भंडार\n- उपशीर्षक: चाट • समोसा • फुल्की\n- मुख्य टेक्स: रंग-बिरंगे मसालों की महफिल, हर प्लेट में देसी प्यार और ताजगी\n- punch line: isse tasty kuch bhi nahi\n- C
# ...

# %%
# Out:
# 'آمريڪا جي راڄڌاني واشنگٽن ڊي سي آهي.'

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)
