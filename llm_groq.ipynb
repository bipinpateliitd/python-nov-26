# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="/home/bipin/Documents/genai/g25-nov-hindi/python-nov/.env")
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="openai/gpt-oss-20b"
)

# %%
output = llm.invoke("What is quantam computing in hindi")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 output = llm.invoke("What is quantam computing in hindi")
#
# File ~/Documents/genai/g25-nov-hindi/python-nov/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
# ...
