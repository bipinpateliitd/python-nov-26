# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="granite3.3:2b"
)

# %%
output= llm.invoke("What is the capital of india")

# %%
output.content
# Out:
# "The capital of India is New Delhi. It's located in the northern part of the country."

# %%
# !ollama list
# Out:
# NAME                                   ID              SIZE      MODIFIED
# granite4:latest                        4235724a127c    2.1 GB    52 minutes ago
# granite3.3:2b                          07bd1f170855    1.5 GB    3 days ago
# granite3.2-vision:latest               3be41a661804    2.4 GB    4 weeks ago
# qwen3-vl:2b                            0635d9d857d4    1.9 GB    4 weeks ago
# granite-embedding:latest               eb4c533ba6f7    62 MB     6 weeks ago
# qwen3-embedding:0.6b-q8_0              ac6da0dfba84    639 MB    6 weeks ago
# qwen3-embedding:0.6b                   ac6da0dfba84    639 MB    6 weeks ago
# embeddinggemma:latest                  85462619ee72    621 MB    6 weeks ago
# granite4:micro                         4235724a127c    2.1 GB    7 weeks ago
# llama3.2:1b                            baf6a787fdff    1.3 GB    2 months ago
# qwen2.5vl:3b                           fb90415cde1e    3.2 GB    3 months ago
# ...
