# %%
msg = "Hello GenAI"

# %%
msg[-1]
# Out:
# 'I'

# %%
msg.lower()
# Out:
# 'hello genai'

# %%
msg.upper()
# Out:
# 'HELLO GENAI'

# %%
msg2 = "GenAI is awesome"

# %%
msg2.split()
# Out:
# ['GenAI', 'is', 'awesome']

# %%
word= "".join(msg2)

# %%
word
# Out:
# 'GenAI is awesome'

# %%
"AI" in "GenAI"
# Out:
# True

# %%
"AI" in msg2
# Out:
# True
