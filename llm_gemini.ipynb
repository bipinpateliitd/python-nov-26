# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="/home/bipin/Documents/genai/g25-nov-hindi/python-nov/.env")
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
output = llm.invoke("what is newtons third law explain in hindi in short")

# %%
print(output.content)
# Out:
# न्यूटन का तीसरा नियम (Newton's Third Law) कहता है:
#
# **"प्रत्येक क्रिया के लिए, एक बराबर और विपरीत प्रतिक्रिया होती है।"**
#
# संक्षेप में इसका मतलब है:
#
# जब एक वस्तु किसी दूसरी वस्तु पर बल लगाती है (क्रिया), तो दूसरी वस्तु भी पहली वस्तु पर उतना ही बल लेकिन विपरीत दिशा में लगाती है (प्रतिक्रिया)।
#
# **उदाहरण:** जब आप दीवार को धक्का देते हैं, तो दीवार भी आपको उतना ही बल विपरीत दिशा में वापस लगाती है।
