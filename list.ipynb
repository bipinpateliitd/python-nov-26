# %%
a=[1, 32,"Suraj",94, "Gyan", 45.5, "This is India"]

# %%
# indexing

a[-7]

# %%
a[6]

# %%
a[1:4:]

# %%
a[0:7:2]

# %%
a[::-1]

# %%
# slicing

# %%
a[4:7:-1]

# %%
a=[1, 32,"Suraj",94, "Gyan", 45.5, "This is India"]

# %%
#append, extend, insert, pop, remove, clear, copy, count, sort, reverse

# %%
a=[1, 32,"Pankaj", 45.5, "Harshit", [2,3,"Manish",4], 92]

# %%
#[2,3,4]

# %%
a
# Out:
# [1, 32, 'Pankaj', 45.5, 'Harshit', [2, 3, 'Manish', 4], 92]

# %%
a[1]
# Out:
# 32

# %%
b=a[5]
b
# Out:
# [2, 3, 'Manish', 4]

# %%
b[2]
# Out:
# 'Manish'

# %%
a[5][2]
# Out:
# 'Manish'

# %%
a=[1, 32,"Pankaj", 45.5, "Harshit", [2,3,"Manish",4,[96,"iphone"],94], 92]

# %%
a[5]
# Out:
# [2, 3, 'Manish', 4, [96, 'iphone'], 94]

# %%
a[5][4]
# Out:
# [96, 'iphone']

# %%
a[5][4][1]
# Out:
# 'iphone'

# %%
# list opeartions

# %%
s=[]
s
# Out:
# []

# %%
type(s)
# Out:
# list

# %%
# adding value in list
# append, extend and insert

# %%
s.append(2)

# %%
s
# Out:
# [2]

# %%
s.append(8)
s
# Out:
# [2, 8]

# %%
s.append("Ayush")
s
# Out:
# [2, 8, 'Ayush']

# %%
# insert

# %%
s
# Out:
# [2, 8, 'Ayush']

# %%
s.insert(1,"Gyan")
s
# Out:
# [2, 'Gyan', 8, 'Ayush']

# %%
s.insert(5,"Gyan")
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 'Gyan']

# %%
s.insert(4,67)
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan']

# %%
s.insert(8,"Ravindra")
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra']

# %%
b=[3,7,54]
b
# Out:
# [3, 7, 54]

# %%
#extend

# %%
s.extend(b)
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra', 3, 7, 54]

# %%
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra', 3, 7, 54]

# %%
a=[1,9,4]
c=[3,9,22]
d=a+c
d
# Out:
# [1, 9, 4, 3, 9, 22]

# %%
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra', 3, 7, 54]

# %%
# pop, remove

# %%
p=s.pop()
# Out:
# ([2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra', 3, 7], 54)

# %%
p
# Out:
# 54

# %%
s
# Out:
# [2, 'Gyan', 8, 'Ayush', 67, 'Gyan', 'Ravindra', 3, 7]

# %%
s.pop(3)
s
# Out:
# [2, 'Gyan', 8, 67, 'Gyan', 'Ravindra', 3, 7]

# %%
s.append(8)
s
# Out:
# [2, 'Gyan', 8, 67, 'Gyan', 'Ravindra', 3, 7, 8]

# %%
s.remove(8)
s
# Out:
# [2, 'Gyan', 67, 'Gyan', 'Ravindra', 3, 7, 8]

# %%
s
# Out:
# [2, 'Gyan', 67, 'Gyan', 'Ravindra', 3, 7, 8]

# %%
q=[34, 97,2,101, 42,83]
q
# Out:
# [34, 97, 2, 101, 42, 83]

# %%
q.sort()
q
# Out:
# [2, 34, 42, 83, 97, 101]

# %%
q.reverse()
q
# Out:
# [101, 97, 83, 42, 34, 2]

# %%
q.extend([3,3,42,42,42])
q
# Out:
# [101, 97, 83, 42, 34, 2, 3, 3, 42, 42, 42]

# %%
q.count(42)
# Out:
# 4

# %%
b=[1,2,3,3,4,5]

# %%
b.append(34)

# %%
b

# %%
b.insert(3,45)
b

# %%
b.extend([2,4,8])

# %%
b

# %%
c=b.pop()
b,c

# %%
c=b.pop(5)
b,c

# %%
b.remove(3)
b

# %%
b.sort()

# %%
b.reverse()
b

# %%
d=b.count(5)
b

# %%
d

# %%
a

# %%
type(a)

# %%
b={2,4}
type(b)

# %%
c={"a":1,"m":5}
type(c)

# %%
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
items = ['a', 'b', 'c', 'd', 'c']

# %%
sp ={}

# %%
sp={"age":45,"name": "Ritesh", "place":"Bihar","phone_number":45788654}

# %%
sp.keys()
# Out:
# dict_keys(['age', 'name', 'place', 'phone_number'])

# %%
sp.values()
# Out:
# dict_values([45, 'Ritesh', 'Bihar', 45788654])

# %%
sp['age']
# Out:
# 45

# %%
sp["phone_number"]
# Out:
# 45788654

# %%
sp={"age":45,"name": "Ritesh", "place":"Bihar","phone_number":45788654,"subjects":["math","science"],"city":"Patna"}

# %%
sp["subjects"][1]
# Out:
# 'science'

# %%
sp["class"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sp["class"]
#
# KeyError: 'class'

# %%
b=sp.get("name")

# %%
b
# Out:
# 'Ritesh'

# %%
sp
# Out:
# {'age': 45,
#  'name': 'Ritesh',
#  'place': 'Bihar',
#  'phone_number': 45788654,
#  'subjects': ['math', 'science'],
#  'city': 'Patna'}

# %%
sp.pop("phone_number")
sp
# Out:
# {'age': 45,
#  'name': 'Ritesh',
#  'place': 'Bihar',
#  'subjects': ['math', 'science'],
#  'city': 'Patna'}

# %%
s.pop("age")

# %%
s

# %%
sp.popitem()
sp
# Out:
# {'age': 45,
#  'name': 'Ritesh',
#  'place': 'Bihar',
#  'subjects': ['math', 'science']}

# %%
del sp["place"]

# %%
sp
# Out:
# {'age': 45, 'name': 'Ritesh', 'subjects': ['math', 'science']}

# %%
student = {'name': 'Alice', 'age': 22, 'city': 'Paris'}

# %%
student.keys()

# %%
student.values()

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
merged = dict1 | dict2
merged
